# %%
d={'1':'one',True:'098765'}
details={'name':'Anshuman','email':'kumaranshuman500@gmail.com'}

# %%
d
# Out:
# {'1': 'one', True: '098765'}

# %%
details['email']
# Out:
# 'kumaranshuman500@gmail.com'

# %%
d[1]
# Out:
# '098765'

# %%
d6={'lucky-number':[1,2,3],'rows':['anshu','raju','kaju']}

# %%
d6['rows']
# Out:
# ['anshu', 'raju', 'kaju']

# %%
d6['height']=[5,4,5.1]

# %%
d6
# Out:
# {'lucky-number': [1, 2, 3],
#  'rows': ['anshu', 'raju', 'kaju'],
#  'height': [5, 4, 5.1]}

# %%
d6.items()
# Out:
# dict_items([('lucky-number', [1, 2, 3]), ('rows', ['anshu', 'raju', 'kaju']), ('height', [5, 4, 5.1])])

# %%
d6.keys()
# Out:
# dict_keys(['lucky-number', 'rows', 'height'])

# %%
l=[1,2,3,4,5,6,7,8,9.0]

# %%
listtoappend=l[0]+1

# %%
l1=[l[0]+1]

# %%
l1.append(l)

# %%
l1
# Out:
# [2, [1, 2, 3, 4, 5, 6, 7, 8, 9.0]]

# %%
l = ["apple", "banana", "mango"]

l1 = []
for i in l:
    print(i)
    l1.append(i.upper())

print(l1)
# Out:
# apple
# banana
# mango
# ['APPLE', 'BANANA', 'MANGO']

# %%
list= ["apple", "banana", "mango",1,2,3,4,5,6,7,8,910,12,111,'@']
l1_num=[]
l2_str=[]
l3_sym=[]
for i in list:
    if type(i)==int or type(i)==float:
        l1_num.append(i)
    elif type(i)==str :
        l2_str.append(i)
    else:
        l3_sym.append(i)

# %%
l1_num
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 910, 12, 111]

# %%
l2_str
# Out:
# ['apple', 'banana', 'mango', '@']

# %%
l3_sym
# Out:
# []
